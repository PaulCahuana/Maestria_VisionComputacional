# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** authored by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu102 (NVIDIA GeForce GTX 1660 SUPER)

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# <img src="https://user-images.githubusercontent.com/26833433/114307955-5c7e4e80-9ae2-11eb-9f50-a90e39bee53f.png" width="900">

# %%
#!python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/
#Image(filename='runs/detect/exp/zidane.jpg', width=600)
# !python detect.py --weights runs/train/exp3/weights/last.pt --img 640 --conf 0.40 --source videos/trafico.mp4
# Out:
# detect: weights=['runs/train/exp3/weights/last.pt'], source=videos/trafico.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-189-gaf00134 torch 1.9.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 5942MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.008s)
# video 1/1 (2/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (3/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (4/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 3 combis, Done. (0.007s)
# video 1/1 (5/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.010s)
# video 1/1 (6/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (7/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (8/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (9/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.008s)
# video 1/1 (10/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (11/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (12/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 4 combis, Done. (0.008s)
# video 1/1 (13/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 4 combis, Done. (0.008s)
# video 1/1 (14/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.008s)
# video 1/1 (15/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 3 combis, Done. (0.007s)
# video 1/1 (16/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 3 combis, Done. (0.007s)
# video 1/1 (17/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 3 combis, Done. (0.007s)
# video 1/1 (18/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (19/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (20/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 4 combis, Done. (0.007s)
# video 1/1 (21/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.009s)
# video 1/1 (22/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (23/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (24/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.007s)
# video 1/1 (25/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.005s)
# video 1/1 (26/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (27/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (28/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (29/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.007s)
# video 1/1 (30/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (31/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.005s)
# video 1/1 (32/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (33/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (34/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.007s)
# video 1/1 (35/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (36/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (37/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (38/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (39/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.008s)
# video 1/1 (40/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (41/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (42/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (43/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (44/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (45/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (46/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (47/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.007s)
# video 1/1 (48/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (49/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.008s)
# video 1/1 (50/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.008s)
# video 1/1 (51/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (52/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (53/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (54/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.005s)
# video 1/1 (55/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (56/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (57/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (58/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (59/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (60/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (61/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.007s)
# video 1/1 (62/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (63/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (64/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (65/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (66/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (67/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.009s)
# video 1/1 (68/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (69/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (70/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.005s)
# video 1/1 (71/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (72/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (73/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.005s)
# video 1/1 (74/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, 1 moto, Done. (0.006s)
# video 1/1 (75/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, 1 moto, Done. (0.005s)
# video 1/1 (76/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, 1 moto, Done. (0.007s)
# video 1/1 (77/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.007s)
# video 1/1 (78/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.006s)
# video 1/1 (79/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, 1 moto, Done. (0.006s)
# video 1/1 (80/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, 1 moto, Done. (0.006s)
# video 1/1 (81/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, 1 moto, Done. (0.005s)
# video 1/1 (82/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.005s)
# video 1/1 (83/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, 1 moto, Done. (0.005s)
# video 1/1 (84/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, 1 moto, Done. (0.005s)
# video 1/1 (85/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, 1 moto, Done. (0.005s)
# video 1/1 (86/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 2 combis, Done. (0.005s)
# video 1/1 (87/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, 1 moto, Done. (0.006s)
# video 1/1 (88/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (89/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (90/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.007s)
# video 1/1 (91/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (92/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (93/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (94/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (95/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.005s)
# video 1/1 (96/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (97/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (98/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.006s)
# video 1/1 (99/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 2 combis, Done. (0.007s)
# video 1/1 (100/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (101/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (102/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.005s)
# video 1/1 (103/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.005s)
# video 1/1 (104/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (105/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (106/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (107/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (108/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (109/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.005s)
# video 1/1 (110/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (111/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.009s)
# video 1/1 (112/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (113/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (114/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (115/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (116/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (117/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (118/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.006s)
# video 1/1 (119/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 3 combis, Done. (0.007s)
# video 1/1 (120/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (121/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (122/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (123/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (124/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (125/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 2 combis, Done. (0.006s)
# video 1/1 (126/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.007s)
# video 1/1 (127/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (128/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (129/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.007s)
# video 1/1 (130/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (131/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (132/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (133/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (134/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (135/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (136/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (137/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (138/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.007s)
# video 1/1 (139/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (140/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (141/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (142/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (143/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (144/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (145/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (146/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.007s)
# video 1/1 (147/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (148/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (149/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (150/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, 1 moto, Done. (0.005s)
# video 1/1 (151/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.005s)
# video 1/1 (152/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.005s)
# video 1/1 (153/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.005s)
# video 1/1 (154/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (155/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (156/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (157/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (158/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.007s)
# video 1/1 (159/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (160/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (161/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (162/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (163/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (164/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (165/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (166/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (167/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (168/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (169/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, 1 moto, Done. (0.007s)
# video 1/1 (170/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (171/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (172/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (173/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (174/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (175/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (176/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (177/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (178/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (179/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (180/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (181/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (182/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (183/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (184/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (185/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (186/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.007s)
# video 1/1 (187/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (188/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (189/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (190/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (191/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (192/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (193/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (194/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (195/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (196/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (197/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (198/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 auto, 1 combi, Done. (0.006s)
# video 1/1 (199/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (200/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 1 combi, Done. (0.006s)
# video 1/1 (201/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.007s)
# video 1/1 (202/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (203/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (204/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (205/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (206/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.007s)
# video 1/1 (207/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (208/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (209/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (210/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 2 autos, 1 combi, Done. (0.006s)
# video 1/1 (211/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 1 combi, Done. (0.006s)
# video 1/1 (212/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 1 combi, Done. (0.006s)
# video 1/1 (213/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 1 combi, Done. (0.006s)
# video 1/1 (214/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (215/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.007s)
# video 1/1 (216/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 1 combi, Done. (0.006s)
# video 1/1 (217/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (218/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (219/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (220/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (221/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 3 autos, 1 combi, Done. (0.006s)
# ...
# video 1/1 (2935/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, Done. (0.006s)
# video 1/1 (2936/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, Done. (0.006s)
# video 1/1 (2937/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, Done. (0.006s)
# video 1/1 (2938/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2939/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2940/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2941/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2942/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2943/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.007s)
# video 1/1 (2944/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2945/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (2946/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (2947/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, 1 moto, Done. (0.005s)
# video 1/1 (2948/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (2949/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, 1 moto, Done. (0.007s)
# video 1/1 (2950/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (2951/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (2952/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (2953/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, 1 moto, Done. (0.005s)
# video 1/1 (2954/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, 1 moto, Done. (0.006s)
# video 1/1 (2955/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.007s)
# video 1/1 (2956/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2957/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 2 combis, Done. (0.006s)
# video 1/1 (2958/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2959/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 2 combis, Done. (0.005s)
# video 1/1 (2960/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 2 combis, Done. (0.006s)
# video 1/1 (2961/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2962/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.008s)
# video 1/1 (2963/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2964/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.009s)
# video 1/1 (2965/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2966/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2967/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2968/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.007s)
# video 1/1 (2969/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2970/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2971/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2972/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2973/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2974/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.005s)
# video 1/1 (2975/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2976/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2977/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2978/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2979/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2980/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2981/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2982/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2983/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2984/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2985/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2986/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 1 combi, Done. (0.006s)
# video 1/1 (2987/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2988/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2989/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 1 combi, Done. (0.006s)
# video 1/1 (2990/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.005s)
# video 1/1 (2991/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.005s)
# video 1/1 (2992/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.006s)
# video 1/1 (2993/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 2 combis, Done. (0.008s)
# video 1/1 (2994/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 2 combis, Done. (0.007s)
# video 1/1 (2995/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.006s)
# video 1/1 (2996/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 6 autos, 2 combis, Done. (0.005s)
# video 1/1 (2997/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 3 combis, Done. (0.006s)
# video 1/1 (2998/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 3 combis, Done. (0.007s)
# video 1/1 (2999/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 3 combis, Done. (0.006s)
# video 1/1 (3000/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 6 autos, 3 combis, Done. (0.006s)
# video 1/1 (3001/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 3 combis, Done. (0.007s)
# video 1/1 (3002/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.006s)
# video 1/1 (3003/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.006s)
# video 1/1 (3004/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.006s)
# video 1/1 (3005/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.005s)
# video 1/1 (3006/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 5 autos, 2 combis, Done. (0.006s)
# video 1/1 (3007/3007) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/ESTUDIOS/MAESTRIA/Curso_5_Vision_Artificial/tarea_final_yolo/yolov5_lima/yolov5/videos/trafico.mp4: 384x640 4 autos, 2 combis, Done. (0.006s)
# Speed: 0.5ms pre-process, 6.0ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val2017
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=819257867.0), HTML(value='')))

# %%
# Run YOLOv5x on COCO val2017
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/coco.yaml', device='', exist_ok=False, half=True, img_size=640, iou_thres=0.65, name='exp', project='runs/val', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['yolov5x.pt'])
# YOLOv5 🚀 v5.0-157-gc6b51f4 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5x.pt to yolov5x.pt...
# 100% 168M/168M [00:01<00:00, 156MB/s]
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients
# val: Scanning '../coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupted: 100% 5000/5000 [00:01<00:00, 3008.87it/s]
# val: New cache created: ../coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [01:17<00:00,  2.02it/s]
#                  all       5000      36335      0.746      0.626       0.68       0.49
# Speed: 5.3/1.5/6.8 ms inference/NMS/total per 640x640 image at batch-size 32
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.44s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=4.88s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=83.47s).
# Accumulating evaluation results...
# DONE (t=12.96s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.546
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
# Results saved to runs/val/exp

# %% [markdown]
# ## COCO test-dev2017
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip # unzip labels
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f && rm $f  # 7GB,  41k images
# %mv ./test2017 ../coco/images  # move to /coco

# %%
# Run YOLOv5s on COCO test-dev2017 using --task test
# !python val.py --weights yolov5s.pt --data coco.yaml --task test

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
# Download COCO128
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22091032.0), HTML(value='')))

# %% [markdown]
# Train a YOLOv5s model on [COCO128](https://www.kaggle.com/ultralytics/coco128) with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and **COCO, COCO128, and VOC datasets are downloaded automatically** on first use.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python3 train.py --img 640 --batch 16 --epochs 50 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v6.0-189-gaf00134 torch 1.9.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 5942MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2022-01-13 19:42:59.652707: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-01-13 19:42:59.652739: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 270 layers, 7027720 parameters, 7027720 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0
0.605
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      32/49     3.55G   0.03433   0.02766  0.002446        90       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381       0.81      0.912      0.916      0.567
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      33/49     3.55G    0.0354   0.02647  0.002715        80       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.886      0.897      0.947      0.544
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      34/49     3.55G   0.03147    0.0292  0.002551       113       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.802      0.894      0.921      0.567
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      35/49     3.55G    0.0327   0.02713  0.002563       117       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.897      0.899       0.95      0.605
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      36/49     3.55G   0.03091   0.02762  0.002329       120       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.882      0.929      0.948      0.634
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      37/49     3.55G   0.03018   0.02705    0.0023       129       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.902      0.921       0.95      0.627
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      38/49     3.55G   0.02877   0.02649  0.002276       131       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.885      0.951      0.959      0.642
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      39/49     3.55G   0.02939   0.02589  0.002161       115       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.883      0.949      0.953      0.672
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      40/49     3.55G   0.02681    0.0265  0.002185        76       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.892      0.942       0.95      0.655
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      41/49     3.55G   0.02633   0.02533  0.001916        86       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.859      0.957      0.947      0.683
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      42/49     3.55G   0.02405   0.02486  0.001869       103       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.876      0.934      0.946      0.668
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      43/49     3.55G   0.02481   0.02562  0.001926        89       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.885      0.918      0.948      0.679
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      44/49     3.55G    0.0227   0.02476  0.001627        90       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.849      0.962      0.947      0.698
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      45/49     3.55G    0.0222   0.02415  0.001476        82       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.878      0.956      0.952      0.705
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      46/49     3.55G   0.02233   0.02397  0.001403       106       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.881      0.946      0.953      0.687
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      47/49     3.55G   0.02184   0.02331  0.001577        92       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.902      0.916      0.951      0.708
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      48/49     3.55G    0.0214   0.02414  0.001463        99       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.901      0.936       0.95      0.714
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      49/49     3.55G   0.02123   0.02353   0.00154        71       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.883       0.95      0.955      0.699
#
# 50 epochs completed in 1.965 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, 14.4MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        118        381      0.901      0.935       0.95       0.71
#                 auto        118        246      0.887      0.955      0.951      0.739
#                combi        118        109      0.927      0.938      0.966      0.804
#                 moto        118         26      0.888      0.913      0.934      0.587
# Results saved to runs/train/exp3

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <img src="https://user-images.githubusercontent.com/26833433/125274843-a27bc600-e30e-11eb-9a44-62af0b7a50a2.png" width="800">

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note a **Mosaic Dataloader** is used for training (shown below), a new concept developed by Ultralytics and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 mosaics and labels
Image(filename='runs/train/exp/test_batch0_labels.jpg', width=800)  # val batch 0 labels
Image(filename='runs/train/exp/test_batch0_pred.jpg', width=800)  # val batch 0 predictions

# %% [markdown]
# > <img src="https://user-images.githubusercontent.com/26833433/124931219-48bf8700-e002-11eb-84f0-e05d95b118dd.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/124931217-4826f080-e002-11eb-87b9-ae0925a8c94b.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/124931209-46f5c380-e002-11eb-9bd5-7a3de2be9851.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_

# %% [markdown]
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and `runs/train/exp/results.txt`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.txt` file manually:

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp')  # plot all results*.txt files in 'runs/train/exp'
Image(filename='runs/train/exp/results.png', width=800)

# %% [markdown]
# <p align="left"><img width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/125273596-6300aa00-e30d-11eb-8dc4-70a960c53013.png"></p>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.25 --iou 0.45  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://github.com/ultralytics/yolov5/raw/master/data/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# Unit tests
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories

rm -rf runs  # remove runs/
for m in yolov5s; do  # models
  python train.py --weights $m.pt --epochs 3 --img 320 --device 0  # train pretrained
  python train.py --weights '' --cfg $m.yaml --epochs 3 --img 320 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # inspect
  python export.py --weights $m.pt --img 640 --batch 1  # export
done

# %%
# Profile
from utils.torch_utils import profile 

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
profile(x=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}
